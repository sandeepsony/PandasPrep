# %% [markdown]
# # 1. Breast Cancer Classification using LAZYPREDICT

# %%
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# %%
data = load_breast_cancer()
X = data.data
y = data.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)

# %%
from IPython.display import display
display(models)

# %% [markdown]
# # 2. Boston Housing Prediction

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn.datasets import fetch_california_housing  # or load_diabetes if you prefer
from sklearn.model_selection import train_test_split
from IPython.display import display
import numpy as np

# Load a sample regression dataset
data = fetch_california_housing()  # Boston housing price dataset
X = data.data
y = data.target

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# Initialize and train LazyRegressor
reg = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)

# Display the performance metrics for all regression models
display(models)
# Out:
#  98%|█████████▊| 41/42 [00:41<00:00,  1.21it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000261 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1838
# [LightGBM] [Info] Number of data points in the train set: 13828, number of used features: 8
# [LightGBM] [Info] Start training from score 2.066636
# 100%|██████████| 42/42 [00:41<00:00,  1.01it/s]
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# LGBMRegressor                                0.84       0.84  0.47        0.60
# HistGradientBoostingRegressor                0.84       0.84  0.47        0.63
# XGBRegressor                                 0.83       0.83  0.47        0.35
# ExtraTreesRegressor                          0.81       0.81  0.51        1.56
# RandomForestRegressor                        0.80       0.80  0.51        4.94
# BaggingRegressor                             0.78       0.79  0.54        0.47
# GradientBoostingRegressor                    0.78       0.78  0.54        1.77
# MLPRegressor                                 0.78       0.78  0.55        3.10
# NuSVR                                        0.73       0.73  0.59        3.52
# SVR                                          0.73       0.73  0.60        3.83
# KNeighborsRegressor                          0.67       0.67  0.66        0.11
# SGDRegressor                                 0.60       0.60  0.73        0.02
# LarsCV                                       0.60       0.60  0.73        0.05
# LassoLarsCV                                  0.60       0.60  0.73        0.07
# LassoCV                                      0.60       0.60  0.73        0.52
# ElasticNetCV                                 0.60       0.60  0.73        0.57
# LassoLarsIC                                  0.60       0.60  0.73        0.14
# BayesianRidge                                0.60       0.60  0.73        0.03
# RidgeCV                                      0.60       0.60  0.73        0.05
# Ridge                                        0.60       0.60  0.73        0.01
# Lars                                         0.60       0.60  0.73        0.01
# TransformedTargetRegressor                   0.60       0.60  0.73        0.01
# LinearRegression                             0.60       0.60  0.73        0.02
# OrthogonalMatchingPursuitCV                  0.60       0.60  0.73        0.01
# DecisionTreeRegressor                        0.59       0.59  0.74        0.11
# HuberRegressor                               0.58       0.58  0.75        0.02
# LinearSVR                                    0.57       0.57  0.76        0.28
# ExtraTreeRegressor                           0.55       0.55  0.78        0.03
# OrthogonalMatchingPursuit                    0.47       0.47  0.84        0.01
# PoissonRegressor                             0.45       0.45  0.86        0.03
# AdaBoostRegressor                            0.44       0.44  0.86        0.51
# TweedieRegressor                             0.39       0.39  0.90        0.12
# GammaRegressor                               0.38       0.38  0.91        0.07
# RANSACRegressor                              0.29       0.29  0.97        0.05
# ElasticNet                                   0.20       0.20  1.03        0.17
# DummyRegressor                              -0.00      -0.00  1.15        0.01
# LassoLars                                   -0.00      -0.00  1.15        0.03
# Lasso                                       -0.00      -0.00  1.15        0.26
# QuantileRegressor                           -0.06      -0.06  1.19        2.39
# PassiveAggressiveRegressor                  -1.30      -1.29  1.75        0.01
# KernelRidge                                 -2.63      -2.63  2.20        4.49
# GaussianProcessRegressor                 -1782.67   -1780.57 48.72       10.55
